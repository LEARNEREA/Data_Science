# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

from mlxtend.feature_selection import SequentialFeatureSelector

# %%
df = pd.read_csv(r"D:\Learnerea\Tables\cancer_data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302         M        17.99         10.38          122.80     1001.0  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df_new = df.drop('id',axis=1)
df_new.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0         M        17.99         10.38          122.80     1001.0  \
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst
# ...

# %%
df_new['diagnosis'] = np.where(df_new['diagnosis']=='M',1,0)

# %%
df_new.to_excel(r"D:\Learnerea\Tables\cancer_data_cleaned.xlsx",index=False)

# %%
df_new.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0          1        17.99         10.38          122.80     1001.0  \
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst
# ...

# %%
df_new.shape
# Out:
# (569, 31)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new.drop('diagnosis',axis=1), df_new.diagnosis, test_size=0.20, random_state=42)

# %%
y_train.head()
# Out:
# 68     0
# 181    1
# 63     0
# 248    0
# 60     0
# Name: diagnosis, dtype: int32

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
feature_selector = SequentialFeatureSelector(LogisticRegression(),
                                            k_features=(5,20),
                                            forward=True,
                                            floating=False,
                                            verbose=4,
                                            scoring="accuracy",
                                            cv=5).fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    1.2s
#
# [2024-04-04 23:16:16] Features: 1/20 -- score: 0.9120879120879121[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    2.5s
#
# [2024-04-04 23:16:20] Features: 2/20 -- score: 0.9428571428571427[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    3.0s
#
# [2024-04-04 23:16:23] Features: 3/20 -- score: 0.9516483516483516[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    3.8s
#
# [2024-04-04 23:16:28] Features: 4/20 -- score: 0.956043956043956[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    4.7s
#
# [2024-04-04 23:16:33] Features: 5/20 -- score: 0.956043956043956[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    5.3s
#
# [2024-04-04 23:16:39] Features: 6/20 -- score: 0.956043956043956[Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=1)]: Done  24 tasks      | elapsed:    5.7s
#
# [2024-04-04 23:16:44] Features: 7/20 -- score: 0.956043956043956
# ...

# %%
feature_selector.k_feature_names_
# Out:
# ('radius_mean',
#  'texture_mean',
#  'area_mean',
#  'smoothness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'smoothness_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst')
