# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge 
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"D:\Learnerea\Tables\cancer_data_cleaned.xlsx")
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0          1        17.99         10.38          122.80     1001.0  \
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst
# ...

# %%
X = df.drop('diagnosis',axis=1)
y = df.diagnosis

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42)

# %%
ridge_reg = Ridge(alpha=1.0)

# %%
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_reg.coef_
# Out:
# array([ 0.10543786, -0.03902779,  0.07231323, -0.13375463,  0.02307077,
#        -0.23703659,  0.04745122,  0.23556031, -0.01566328,  0.00347173,
#         0.17361698, -0.04860694,  0.00605728, -0.1136715 ,  0.06666551,
#        -0.02918685, -0.12979992,  0.0982854 , -0.01282038,  0.01060335,
#         0.29566164,  0.13194318, -0.02026447, -0.20852639, -0.02056608,
#         0.09737568,  0.17472187, -0.09331118,  0.07080295,  0.02462609])

# %%
feature_importance = [(feature,coef) for feature,coef in zip(X.columns,ridge_reg.coef_)]
feature_importance
# Out:
# [('radius_mean', 0.10543785787612611),
#  ('texture_mean', -0.03902778841847888),
#  ('perimeter_mean', 0.07231323115390113),
#  ('area_mean', -0.13375462955139597),
#  ('smoothness_mean', 0.023070765728991045),
#  ('compactness_mean', -0.23703659180022874),
#  ('concavity_mean', 0.04745121595847305),
#  ('concave points_mean', 0.23556031211549452),
#  ('symmetry_mean', -0.015663281260063125),
#  ('fractal_dimension_mean', 0.0034717261515735186),
#  ('radius_se', 0.17361698376060386),
#  ('texture_se', -0.04860694253696971),
#  ('perimeter_se', 0.006057280396463324),
#  ('area_se', -0.11367150084791275),
#  ('smoothness_se', 0.06666551137364608),
#  ('compactness_se', -0.02918685292526104),
#  ('concavity_se', -0.12979992489238293),
#  ('concave points_se', 0.09828539850701597),
#  ('symmetry_se', -0.012820377490392353),
#  ('fractal_dimension_se', 0.010603345098422508),
#  ('radius_worst', 0.29566163743752294),
#  ('texture_worst', 0.13194317626971905),
# ...

# %%
fi_df = pd.DataFrame(feature_importance,columns=['features','coef'])
fi_df.sort_values(by='coef',ascending=False)
# Out:
#                    features      coef
# 20             radius_worst  0.295662
# 7       concave points_mean  0.235560
# 26          concavity_worst  0.174722
# 10                radius_se  0.173617
# 21            texture_worst  0.131943
# 0               radius_mean  0.105438
# 17        concave points_se  0.098285
# 25        compactness_worst  0.097376
# 2            perimeter_mean  0.072313
# 28           symmetry_worst  0.070803
# 14            smoothness_se  0.066666
# 6            concavity_mean  0.047451
# 29  fractal_dimension_worst  0.024626
# 4           smoothness_mean  0.023071
# 19     fractal_dimension_se  0.010603
# 12             perimeter_se  0.006057
# 9    fractal_dimension_mean  0.003472
# 18              symmetry_se -0.012820
# 8             symmetry_mean -0.015663
# 22          perimeter_worst -0.020264
# 24         smoothness_worst -0.020566
# 15           compactness_se -0.029187
# 1              texture_mean -0.039028
# 11               texture_se -0.048607
# ...
